# %%
import os

import pandas as pd
import numpy as np

import pyproj
import geocoder

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9fada9f5-c798-4532-aff1-0f330d138aef">Loading BokehJS ...</span>
#     </div>

# %%
# transform coords to map projection
wgs84 = pyproj.Proj(init="epsg:4326")
webMer = pyproj.Proj(init="epsg:3857")
df["easting"] = "NaN"
df["northing"] = "NaN"
df["easting"] = df["easting"].astype("float64")
df["northing"] = df["northing"].astype("float64")
df.loc[pd.notnull(df["Decimal Longitude"]), "easting"], df.loc[pd.notnull(df["Decimal Latitude"]), "northing"] = zip(
    *df.loc[pd.notnull(df["Decimal Longitude"])], df.loc[pd.notnull(df["Decimal Latitude"])].apply(
        lambda x: pyproj.transform(wgs84, webMer, x["Decimal Longitude"], x["Decimal Latitude"]), axis=1))
